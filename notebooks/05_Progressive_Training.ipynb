# %%
# CELL 0: Environment setup + symlink repair
import sys, os
from pathlib import Path

# ── Locate project root ────────────────────────────────────────────
cwd = Path.cwd()
if cwd.name == "notebooks":
    project_root = cwd.parent
else:
    project_root = cwd
os.chdir(project_root)
sys.path.insert(0, str(project_root))
print(f"✅ Working dir: {os.getcwd()}")

# ── Repair notebooks/data symlink if broken ────────────────────────
notebooks_dir = project_root / "notebooks"
symlink_path  = notebooks_dir / "data"
target_path   = project_root / "data"

if not target_path.exists():
    raise RuntimeError(f"❌ data/ folder missing at {target_path} — check WSL mount")

if symlink_path.is_symlink():
    print(f"✅ Symlink already exists: notebooks/data → {os.readlink(symlink_path)}")
elif symlink_path.exists():
    print(f"⚠️ notebooks/data exists but is NOT a symlink (probably a git stub) — removing and recreating...")
    if symlink_path.is_file():
        symlink_path.unlink()
    else:
        import shutil
        shutil.rmtree(symlink_path)
    symlink_path.symlink_to(target_path)
    print(f"✅ Symlink recreated: notebooks/data → {target_path}")
else:
    symlink_path.symlink_to(target_path)
    print(f"✅ Symlink created: notebooks/data → {target_path}")

# ── Verify data paths resolve ──────────────────────────────────────
checks = [
    "data/processed/telangana_population_sequence.npy",
    "data/processed/maharashtra_population_sequence.npy",
    "data/processed/india_sample.h5",
    "models/checkpoints",
    "src/config.py",
]
all_ok = True
for p in checks:
    exists = Path(p).exists()
    print(f"{'✅' if exists else '❌'} {p}")
    if not exists: all_ok = False

if all_ok:
    print("\n✅ All paths verified — safe to run remaining cells")
else:
    raise RuntimeError("❌ Some paths missing — fix before continuing")
# Out:
# ✅ Working dir: /workspace
# ✅ Symlink already exists: notebooks/data → /workspace/data
# ✅ data/processed/telangana_population_sequence.npy
# ✅ data/processed/maharashtra_population_sequence.npy
# ✅ data/processed/india_sample.h5
# ✅ models/checkpoints
# ✅ src/config.py
#
# ✅ All paths verified — safe to run remaining cells

# %%
# Cell 1 — Imports + Config
import sys, os, torch, torch.nn as nn, torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import numpy as np, h5py, json, time, logging
from pathlib import Path
from tqdm.notebook import tqdm as tqdm_nb
from datetime import datetime
import warnings; warnings.filterwarnings("ignore")
from src.config import TrainingConfig

config    = TrainingConfig()
device    = config.DEVICE
LOAD_MODE = config.DATA_MODE   # ← from .env

Path("logs").mkdir(exist_ok=True)
logging.basicConfig(filename="logs/training.log", level=logging.INFO,
                    format="%(asctime)s - %(message)s")

print("=" * 70)
print("NOTEBOOK 05 — PROGRESSIVE TRAINING")
print("=" * 70)
config.print_summary()

# ── CPU threading ──────────────────────────────────────────
import torch
if not torch.has_mkl or torch.get_num_threads() == 1:
    torch.set_num_threads(os.cpu_count())

try:
    torch.set_num_interop_threads(os.cpu_count() // 2)
except RuntimeError:
    pass  # already set — safe to ignore on re-runs

print(f"⚙️  PyTorch threads       : {torch.get_num_threads()}")
print(f"⚙️  DataLoader workers    : 2")
# Out:
# ======================================================================
# NOTEBOOK 05 — PROGRESSIVE TRAINING
# ======================================================================
#
# ======================================================================
# 🚀 CIVICPULSE TRAINING CONFIGURATION (Benchmark-Optimized)
# ======================================================================
# Device           : cuda
# VRAM Available   : 12.7 GB
# Batch Size       : 64
# Data Mode        : normal
# Patch Size       : 256×256 cells
# ConvLSTM         : 64 hidden, 2 layers
# Learning Rate    : 0.001
# Sequence Length  : 4 timesteps
# ======================================================================
#
# ⚙️  PyTorch threads       : 6
# ⚙️  DataLoader workers    : 2

# %%
# Cell 2 — Dataset Classes (HDF5 and Normal)
class PopulationDatasetHDF5(Dataset):
    """Lazy HDF5 dataset — low RAM."""
    def __init__(self, h5_path, patch_size=64, stride=32, downsample=1):
        self.h5_path    = h5_path
        self.patch_size = patch_size
        self.stride     = stride
        self.downsample = downsample
        
        with h5py.File(h5_path, "r") as h5:
            shape = h5["population_data"].shape
        self.height  = shape[1] // downsample
        self.width   = shape[2] // downsample
        self.patches = [(y, x)
                        for y in range(0, self.height - patch_size, stride)
                        for x in range(0, self.width  - patch_size, stride)]

    def __len__(self): return len(self.patches)

    def __getitem__(self, idx):
        y, x = self.patches[idx]
        ds, ps = self.downsample, self.patch_size
        with h5py.File(self.h5_path, "r") as h5:
            data = h5["population_data"][:,
                       y*ds:(y+ps)*ds:ds,
                       x*ds:(x+ps)*ds:ds]
        X  = torch.from_numpy(data[:4].copy()).float().unsqueeze(1)
        y_ = torch.from_numpy(data[4].copy()).float().unsqueeze(0)
        return X, y_


class PopulationDatasetNormal(Dataset):
    """Full in-memory dataset."""
    def __init__(self, data_array, patch_size=64, stride=32):
        self.data       = data_array
        self.patch_size = patch_size
        T, H, W = data_array.shape
        self.patches = [(y, x)
                        for y in range(0, H - patch_size, stride)
                        for x in range(0, W - patch_size, stride)]

    def __len__(self): return len(self.patches)

    def __getitem__(self, idx):
        y, x = self.patches[idx]
        ps   = self.patch_size
        data = self.data[:, y:y+ps, x:x+ps]
        X  = torch.from_numpy(data[:4].copy()).float().unsqueeze(1)
        y_ = torch.from_numpy(data[4].copy()).float().unsqueeze(0)
        return X, y_


def make_dataset(h5_path, normal_data, patch_size, stride, downsample):
    """Factory: returns correct dataset based on LOAD_MODE."""
    if LOAD_MODE == "hdf5":
        return PopulationDatasetHDF5(h5_path, patch_size, stride, downsample)
    else:
        return PopulationDatasetNormal(normal_data, patch_size, stride)

# %%
# Cell 3 — Load Data (mode-aware)
h5_path     = "data/processed/india_sample.h5"
normal_data = None

if LOAD_MODE == "hdf5":
    print("📂 HDF5 mode — data will be loaded lazily per patch.")
    with h5py.File(h5_path, "r") as h5:
        print(f"  Dataset shape: {h5['population_data'].shape}")
else:
    print("📂 Normal mode — loading full arrays into RAM...")
    tel  = np.load("data/processed/telangana_population_sequence.npy")
    maha = np.load("data/processed/maharashtra_population_sequence.npy")
    T, H1, W1 = tel.shape
    _,  H2, W2 = maha.shape
    maxH, maxW = max(H1,H2), max(W1,W2)
    tel  = np.pad(tel,  ((0,0),(0,maxH-H1),(0,maxW-W1)))
    maha = np.pad(maha, ((0,0),(0,maxH-H2),(0,maxW-W2)))
    normal_data = np.concatenate([tel, maha], axis=1).astype(np.float32)
    print(f"  Full array loaded: {normal_data.shape}")
# Out:
# 📂 Normal mode — loading full arrays into RAM...
#   Full array loaded: (5, 6902, 3508)

# %%
# Cell 4 — Model classes (copy from NB04)

class ConvLSTMCell(nn.Module):
    def __init__(self, in_channels, hidden_channels, kernel_size=3):
        super().__init__()
        self.hidden_channels = hidden_channels
        padding = kernel_size // 2
        self.conv_gates = nn.Conv2d(
            in_channels + hidden_channels, 2 * hidden_channels, kernel_size, padding=padding)
        self.conv_candidate = nn.Conv2d(
            in_channels + hidden_channels, hidden_channels, kernel_size, padding=padding)

    def forward(self, inputs, hidden_state):
        h, c = hidden_state
        combined = torch.cat([inputs, h], dim=1)
        gates = self.conv_gates(combined)
        reset_gate, update_gate = torch.split(gates, self.hidden_channels, dim=1)
        reset_gate  = torch.sigmoid(reset_gate)
        update_gate = torch.sigmoid(update_gate)
        combined_candidate = torch.cat([inputs, reset_gate * h], dim=1)
        candidate = torch.tanh(self.conv_candidate(combined_candidate))
        new_c = (1 - update_gate) * c + update_gate * candidate
        new_h = torch.tanh(new_c) * update_gate + (1 - update_gate) * h
        return new_h, new_c


class ConvLSTMEncoderDecoder(nn.Module):
    def __init__(self, in_channels=1,
                 hidden_channels=None, num_layers=None, kernel_size=3):
        super().__init__()
        # Pull from config if not explicitly passed
        _cfg = TrainingConfig()
        hidden_channels = hidden_channels or _cfg.HIDDEN_CHANNELS
        num_layers      = num_layers      or _cfg.NUM_LAYERS
        self.hidden_channels = hidden_channels
        self.num_layers      = num_layers
        self.encoder_cells = nn.ModuleList([
            ConvLSTMCell(in_channels if i == 0 else hidden_channels,
                         hidden_channels, kernel_size)
            for i in range(num_layers)])
        self.decoder_cells = nn.ModuleList([
            ConvLSTMCell(hidden_channels, hidden_channels, kernel_size)
            for _ in range(num_layers)])
        self.output_conv = nn.Conv2d(hidden_channels, 1, kernel_size=1)

    def forward(self, x):
        B, T, C, H, W = x.shape
        h = [torch.zeros(B, self.hidden_channels, H, W, device=x.device, dtype=x.dtype)
             for _ in range(self.num_layers)]
        c = [torch.zeros(B, self.hidden_channels, H, W, device=x.device, dtype=x.dtype)
             for _ in range(self.num_layers)]
        for t in range(T):
            xt = x[:, t]
            for layer in range(self.num_layers):
                h[layer], c[layer] = self.encoder_cells[layer](
                    xt if layer == 0 else h[layer-1], (h[layer], c[layer]))
        for layer in range(self.num_layers):
            inp = h[layer-1] if layer > 0 else h[0]
            h[layer], c[layer] = self.decoder_cells[layer](inp, (h[layer], c[layer]))
        return self.output_conv(h[-1])   # (B, 1, H, W)

class PopulationLoss(nn.Module):
    def __init__(self, alpha=0.7, beta=0.3):
        super().__init__()
        self.alpha, self.beta = alpha, beta
        self.mse = nn.MSELoss()
        self.mae = nn.L1Loss()

    def forward(self, pred, target):
        mse  = self.mse(pred, target)
        mae  = self.mae(pred, target)
        pc   = torch.clamp(pred,   min=0)
        tc   = torch.clamp(target, min=0)
        mask = tc > 1.0
        rel  = (torch.abs(pc[mask] - tc[mask]) / (tc[mask] + 1e-8)).mean() \
               if mask.sum() > 0 else torch.tensor(0.0, device=pred.device)
        return self.alpha * mse + self.beta * mae + 0.1 * rel

def calculate_r2(pred, target):
    ss_res = ((pred - target) ** 2).sum()
    ss_tot = ((target - target.mean()) ** 2).sum()
    return (1 - ss_res / ss_tot).item()

criterion = PopulationLoss()
print("✅ Model classes and loss function defined")
# Out:
# ✅ Model classes and loss function defined

# %%
# Cell 5 — Training Stages Config
import gc

STAGE3_BATCH = 16        # reduced for VRAM; grad accum simulates effective 64
STAGE3_ACCUM = 4         # 16 × 4 = effective batch 64

training_stages = {
    "stage1_coarse": dict(
        downsample=4, patch_size=32,
        batch_size=config.BATCH_SIZE,
        epochs=20, lr=1e-3, name="Stage 1 — Coarse",
        accum_steps=1),
    "stage2_medium": dict(
        downsample=2, patch_size=64,
        batch_size=config.BATCH_SIZE,
        epochs=50, lr=5e-4, name="Stage 2 — Medium",
        accum_steps=1),
    "stage3_fine": dict(
        downsample=1, patch_size=128,
        batch_size=STAGE3_BATCH,      # ← 16 instead of 64
        epochs=100, lr=1e-4, name="Stage 3 — Fine",
        accum_steps=STAGE3_ACCUM),    # ← gradient accumulation
}
for s, cfg in training_stages.items():
    print(f"{cfg['name']} | ds={cfg['downsample']} "
          f"patch={cfg['patch_size']} bs={cfg['batch_size']} "
          f"ep={cfg['epochs']} accum={cfg['accum_steps']}")
# Out:
# Stage 1 — Coarse | ds=4 patch=32 bs=64 ep=20 accum=1
# Stage 2 — Medium | ds=2 patch=64 bs=64 ep=50 accum=1
# Stage 3 — Fine | ds=1 patch=128 bs=16 ep=100 accum=4

# %%
# Cell 6 — Trainer Class
class Trainer:
    def __init__(self, model, device, checkpoint_dir="models/checkpoints"):
        self.model    = model.to(device)
        self.device   = device
        self.ckpt_dir = Path(checkpoint_dir)
        self.ckpt_dir.mkdir(parents=True, exist_ok=True)

    def save_checkpoint(self, epoch, stage, loss, r2, is_best=False):
        ckpt = dict(epoch=epoch, stage=stage,
                    model_state=self.model.state_dict(), loss=loss, r2=r2)
        torch.save(ckpt, self.ckpt_dir / f"ckpt_{stage}_ep{epoch}.pt")
        if is_best:
            torch.save(ckpt, self.ckpt_dir / "best_model.pt")

# %%
# Cell 7 — Progressive Training Loop
from tqdm.notebook import tqdm as tqdm_nb

model = ConvLSTMEncoderDecoder().to(device)
trainer = Trainer(model, device)
criterion = PopulationLoss()
all_history = {}
TOTAL_STAGES = len(training_stages)

print(f"⚙️ PyTorch threads : {torch.get_num_threads()}")
print(f"⚙️ DataLoader workers : 2")

for stage_idx, (stage_name, cfg) in enumerate(training_stages.items(), 1):
    # ── VRAM cleanup before each stage ─────────────────────
    torch.cuda.empty_cache()
    gc.collect()
    free_gb = torch.cuda.mem_get_info()[0] / 1e9
    print(f"\n{'='*70}")
    print(f"[{stage_idx}/{TOTAL_STAGES}] {cfg['name']}  |  VRAM free: {free_gb:.1f} GB")
    print(f"  patch={cfg['patch_size']} downsample={cfg['downsample']} "
          f"batch={cfg['batch_size']} epochs={cfg['epochs']} lr={cfg['lr']}")
    print(f"{'='*70}")

    dataset = make_dataset(
        h5_path, normal_data,
        patch_size=cfg["patch_size"],
        stride=cfg["patch_size"] // 2,
        downsample=cfg["downsample"])

    train_sz = int(0.8 * len(dataset))
    val_sz = len(dataset) - train_sz
    train_set, val_set = torch.utils.data.random_split(dataset, [train_sz, val_sz])

    train_loader = DataLoader(train_set, batch_size=cfg["batch_size"],
                              shuffle=True, num_workers=0)
    val_loader   = DataLoader(val_set,   batch_size=cfg["batch_size"],
                              shuffle=False, num_workers=0)

    print(f"  {len(dataset)} patches → train={train_sz} / val={val_sz} "
          f"({len(train_loader)} train batches / {len(val_loader)} val batches)")

    optimizer = optim.Adam(model.parameters(), lr=cfg["lr"])
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", factor=0.5, patience=5)

    ACCUM = cfg["accum_steps"]   # 1 for stages 1&2, 4 for stage 3
    history  = dict(train_loss=[], train_r2=[], val_loss=[], val_r2=[])
    best_r2  = -np.inf
    stage_start = time.time()

    epoch_bar = tqdm_nb(range(1, cfg["epochs"] + 1),
                        desc=f"  {cfg['name']}", unit="ep", leave=True)

    for epoch in epoch_bar:
        # ── Train ──────────────────────────────────────────────
        model.train()
        total_loss = total_r2 = 0
        batch_bar = tqdm_nb(train_loader, desc="   Train", leave=False,
                            unit="batch", mininterval=0.5)

        optimizer.zero_grad()
        for i, (X, y) in enumerate(batch_bar):
            X, y = X.to(device), y.to(device)
            out  = model(X)
            loss = criterion(out, y) / ACCUM   # scale loss for accumulation
            loss.backward()

            if (i + 1) % ACCUM == 0 or (i + 1) == len(train_loader):
                torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
                optimizer.step()
                optimizer.zero_grad()

            total_loss += loss.item() * ACCUM  # unscale for logging
            total_r2   += calculate_r2(out.detach(), y.detach())

        n = len(train_loader)
        tr_loss, tr_r2 = total_loss / n, total_r2 / n

        # ── Validate ───────────────────────────────────────────
        model.eval()
        vl_loss_sum = vl_r2_sum = 0
        val_bar = tqdm_nb(val_loader, desc="   Val ", leave=False,
                          unit="batch", mininterval=0.5)
        with torch.no_grad():
            for X, y in val_bar:
                X, y = X.to(device), y.to(device)
                out   = model(X)
                vl_loss_sum += criterion(out, y).item()
                vl_r2_sum   += calculate_r2(out, y)
        n = len(val_loader)
        vl_loss, vl_r2 = vl_loss_sum / n, vl_r2_sum / n

        history["train_loss"].append(tr_loss)
        history["train_r2"].append(tr_r2)
        history["val_loss"].append(vl_loss)
        history["val_r2"].append(vl_r2)

        is_best = vl_r2 > best_r2
        if is_best: best_r2 = vl_r2
        trainer.save_checkpoint(epoch, stage_name, vl_loss, vl_r2, is_best=is_best)

        epoch_bar.set_postfix(
            tr_L=f"{tr_loss:.0f}", tr_R2=f"{tr_r2:.3f}",
            vl_L=f"{vl_loss:.0f}", vl_R2=f"{vl_r2:.3f}",
            best=f"{best_r2:.3f}")

        scheduler.step(vl_r2)
        logging.info(f"{stage_name} ep{epoch} tr={tr_loss:.4f}/{tr_r2:.3f} "
                     f"val={vl_loss:.4f}/{vl_r2:.3f}")

    stage_mins = (time.time() - stage_start) / 60
    all_history[stage_name] = history
    print(f"  ✅ {cfg['name']} done in {stage_mins:.1f} min | Best Val R²={best_r2:.3f}")

with open("logs/training_summary.json", "w") as f:
    json.dump({k: {kk: vv[-1] for kk, vv in v.items()}
               for k, v in all_history.items()}, f, indent=2)
print("\n✅ Training summary → logs/training_summary.json")
print("✅ Best model → models/checkpoints/best_model.pt")
# Out:
# ⚙️ PyTorch threads : 6
# ⚙️ DataLoader workers : 2
#
# ======================================================================
# [1/3] Stage 1 — Coarse  |  VRAM free: 11.4 GB
#   patch=32 downsample=4 batch=64 epochs=20 lr=0.001
# ======================================================================
#   93740 patches → train=74992 / val=18748 (1172 train batches / 293 val batches)
#   Stage 1 — Coarse:   0%|          | 0/20 [00:00<?, ?ep/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/1172 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/293 [00:00<?, ?batch/s]
#   ✅ Stage 1 — Coarse done in 47.0 min | Best Val R²=0.502
#
# ======================================================================
# [2/3] Stage 2 — Medium  |  VRAM free: 11.1 GB
#   patch=64 downsample=2 batch=64 epochs=50 lr=0.0005
# ======================================================================
#   23112 patches → train=18489 / val=4623 (289 train batches / 73 val batches)
#   Stage 2 — Medium:   0%|          | 0/50 [00:00<?, ?ep/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/289 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/73 [00:00<?, ?batch/s]
#   ✅ Stage 2 — Medium done in 132.1 min | Best Val R²=0.469
#
# ======================================================================
# [3/3] Stage 3 — Fine  |  VRAM free: 11.1 GB
#   patch=128 downsample=1 batch=16 epochs=100 lr=0.0001
# ======================================================================
#   5618 patches → train=4494 / val=1124 (281 train batches / 71 val batches)
#   Stage 3 — Fine:   0%|          | 0/100 [00:00<?, ?ep/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#    Train:   0%|          | 0/281 [00:00<?, ?batch/s]
#    Val :   0%|          | 0/71 [00:00<?, ?batch/s]
#   ✅ Stage 3 — Fine done in 260.4 min | Best Val R²=-inf
#
# ✅ Training summary → logs/training_summary.json
# ✅ Best model → models/checkpoints/best_model.pt

# %%
import torch

# Load the final Stage 3 checkpoint (last epoch)
stage3_ckpt = torch.load("models/checkpoints/ckpt_stage3_fine_ep100.pt")
print(f"Stage 3 final — epoch: {stage3_ckpt['epoch']}, loss: {stage3_ckpt['loss']:.2f}")
# Out:
# Stage 3 final — epoch: 100, loss: 138726.10

# %%
torch.save(stage3_ckpt, "models/checkpoints/best_model.pt")
print("✅ best_model.pt updated to Stage 3 final weights")
# Out:
# ✅ best_model.pt updated to Stage 3 final weights

# %%
import torch
ckpt = torch.load("models/checkpoints/best_model.pt")
print(f"Saved at epoch : {ckpt['epoch']}")
print(f"Stage          : {ckpt['stage']}")
print(f"Val R²         : {ckpt['r2']:.4f}")
print(f"Val Loss       : {ckpt['loss']:.2f}")
# Out:
# Saved at epoch : 100
# Stage          : stage3_fine
# Val R²         : -inf
# Val Loss       : 138726.10

# %% [markdown]
# # stage 3 fix: resolve corrupted stage 3 with lower batch and patch sizes #

# %%
import gc
model = ConvLSTMEncoderDecoder().to(device)
trainer = Trainer(model, device)
criterion = PopulationLoss()
print("Model and trainer ready")
# Out:
# Model and trainer ready

# %%
# CELL A: Restore best Stage 2 weights
import torch
from pathlib import Path

ckpt_dir = Path("models/checkpoints")

# Debug: show what's actually there
all_ckpts = sorted(ckpt_dir.glob("ckpt_*.pt"))
print(f"All checkpoints found ({len(all_ckpts)}):")
for f in all_ckpts[-5:]:
    print(f"  {f.name}")

# Match actual filename pattern
stage2_ckpts = sorted(ckpt_dir.glob("ckpt_stage2_medium_ep*.pt"))
if not stage2_ckpts:
    stage2_ckpts = sorted(ckpt_dir.glob("*stage2*ep*.pt"))
    print(f"Fallback search found: {[f.name for f in stage2_ckpts]}")

if stage2_ckpts:
    # Find best R² across all Stage 2 epochs
    best_ckpt = None
    best_r2   = -float('inf')
    for path in stage2_ckpts:
        ckpt = torch.load(path, map_location=device)
        r2   = ckpt.get('r2', -float('inf'))
        if r2 > best_r2:
            best_r2  = r2
            best_ckpt = (path, ckpt)

    path, ckpt = best_ckpt
    print(f"\n✅ Best Stage 2 checkpoint: {path.name}")
    print(f"   Epoch: {ckpt['epoch']} | R²: {ckpt['r2']:.4f} | Loss: {ckpt['loss']:.2f}")
    torch.save(ckpt, ckpt_dir / "best_model.pt")
    print("✅ best_model.pt restored to best Stage 2 weights")
else:
    print("❌ No Stage 2 checkpoints found!")
# Out:
# All checkpoints found (170):
#   ckpt_stage3_fine_ep95.pt
#   ckpt_stage3_fine_ep96.pt
#   ckpt_stage3_fine_ep97.pt
#   ckpt_stage3_fine_ep98.pt
#   ckpt_stage3_fine_ep99.pt
#
# ✅ Best Stage 2 checkpoint: ckpt_stage2_medium_ep50.pt
#    Epoch: 50 | R²: 0.4691 | Loss: 111432.81
# ✅ best_model.pt restored to best Stage 2 weights

# %%
# CELL B: Re-run Stage 3 — fixed patch size, NaN-safe R², early stopping
import gc, time
import numpy as np
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm as tqdm_nb

def calculate_r2_safe(pred, target):
    ss_res = ((pred - target) ** 2).sum()
    ss_tot = ((target - target.mean()) ** 2).sum()
    if ss_tot < 1e-8:
        return 0.0
    val = (1 - ss_res / ss_tot).item()
    return val if (val == val and val > -1e6) else 0.0

stage3_fixed = dict(
    downsample=1,
    patch_size=64,       # was 128 → ~90k patches instead of 5k
    batch_size=16,
    max_epochs=50,       # soft limit — early stopping may end sooner
    lr=1e-4,
    name="stage3_fine_fixed",
    accum_steps=4,       # effective batch = 16 × 4 = 64
)

cfg = stage3_fixed
torch.cuda.empty_cache(); gc.collect()
free_gb = torch.cuda.mem_get_info()[0] / 1e9
print(f"{'='*70}")
print(f"Stage 3 Fine FIXED | VRAM free: {free_gb:.1f} GB")
print(f"patch={cfg['patch_size']} ds={cfg['downsample']} "
      f"bs={cfg['batch_size']} max_ep={cfg['max_epochs']} lr={cfg['lr']}")

# Load best Stage 2 weights
best_ckpt_path = Path("models/checkpoints/best_model.pt")
if best_ckpt_path.exists():
    ckpt = torch.load(best_ckpt_path, map_location=device)
    model.load_state_dict(ckpt['model_state'])
    print(f"✅ Loaded Stage 2 weights — R²: {ckpt['r2']:.4f}")
else:
    print("⚠️  No best_model.pt found — starting from scratch")

# Build dataset
dataset = make_dataset(
    h5_path, normal_data,
    patch_size=cfg['patch_size'],
    stride=cfg['patch_size'] // 2,
    downsample=cfg['downsample']
)
train_sz = int(0.8 * len(dataset))
val_sz   = len(dataset) - train_sz
trainset, valset = torch.utils.data.random_split(dataset, [train_sz, val_sz])
trainloader = DataLoader(trainset, batch_size=cfg['batch_size'],
                         shuffle=True,  num_workers=0, pin_memory=True)
valloader   = DataLoader(valset,   batch_size=cfg['batch_size'],
                         shuffle=False, num_workers=0, pin_memory=True)
print(f"{len(dataset)} patches | train {train_sz} val {val_sz} | "
      f"{len(trainloader)} train batches | {len(valloader)} val batches")

optimizer = optim.Adam(model.parameters(), lr=cfg['lr'])
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.5, patience=5)
ACCUM   = cfg['accum_steps']
PATIENCE = 10

history = dict(train_loss=[], train_r2=[], val_loss=[], val_r2=[])
best_r2 = -np.inf
last_improvement_epoch = 0
stage_start = time.time()

epoch_bar = tqdm_nb(range(1, cfg['max_epochs'] + 1),
                    desc="Stage 3 Fine Fixed", unit='ep', leave=True)

for epoch in epoch_bar:
    # ── Train ──────────────────────────────────────────────────────
    model.train()
    total_loss = total_r2 = 0
    optimizer.zero_grad()
    batch_bar = tqdm_nb(trainloader, desc='Train', leave=False,
                        unit='batch', mininterval=0.5)
    for i, (X, y) in enumerate(batch_bar, 1):
        X, y  = X.to(device), y.to(device)
        out   = model(X)
        loss  = criterion(out, y) / ACCUM
        loss.backward()
        if i % ACCUM == 0 or i == len(trainloader):
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            optimizer.zero_grad()
        total_loss += loss.item() * ACCUM
        total_r2   += calculate_r2_safe(out.detach(), y.detach())
    n = len(trainloader)
    tr_loss, tr_r2 = total_loss / n, total_r2 / n

    # ── Validate ───────────────────────────────────────────────────
    model.eval()
    vl_loss_sum = vl_r2_sum = 0
    with torch.no_grad():
        for X, y in valloader:
            X, y = X.to(device), y.to(device)
            out  = model(X)
            vl_loss_sum += criterion(out, y).item()
            vl_r2_sum   += calculate_r2_safe(out, y)
    n = len(valloader)
    vl_loss, vl_r2 = vl_loss_sum / n, vl_r2_sum / n

    history['train_loss'].append(tr_loss)
    history['train_r2'].append(tr_r2)
    history['val_loss'].append(vl_loss)
    history['val_r2'].append(vl_r2)

    # ── Checkpoint ────────────────────────────────────────────────
    is_best = vl_r2 > best_r2
    if is_best:
        best_r2 = vl_r2
        last_improvement_epoch = epoch
        trainer.save_checkpoint(epoch, cfg['name'], vl_loss, vl_r2, is_best=True)
        print(f"\n  ✅ New best at epoch {epoch}: R²={vl_r2:.4f} | Loss={vl_loss:.2f}")

    trainer.save_checkpoint(epoch, cfg['name'], vl_loss, vl_r2, is_best=False)
    epoch_bar.set_postfix(
        trL=f"{tr_loss:.0f}",  trR2=f"{tr_r2:.3f}",
        vlL=f"{vl_loss:.0f}",  vlR2=f"{vl_r2:.3f}",
        best=f"{best_r2:.3f}")
    scheduler.step(vl_r2)

    # ── Early stopping ────────────────────────────────────────────
    if epoch - last_improvement_epoch >= PATIENCE:
        print(f"\n⏹  Early stopping at epoch {epoch} "
              f"(no improvement for {PATIENCE} epochs)")
        break

stage_mins = (time.time() - stage_start) / 60
print(f"\n{'='*70}")
print(f"Stage 3 done in {stage_mins:.1f} min | Best Val R²: {best_r2:.3f}")
print(f"Stopped at epoch {epoch} / {cfg['max_epochs']}")
# Out:
# ======================================================================
# Stage 3 Fine FIXED | VRAM free: 10.3 GB
# patch=64 ds=1 bs=16 max_ep=50 lr=0.0001
# ✅ Loaded Stage 2 weights — R²: 0.4691
# 23112 patches | train 18489 val 4623 | 1156 train batches | 289 val batches
# Stage 3 Fine Fixed:   0%|          | 0/50 [00:00<?, ?ep/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 1: R²=0.6026 | Loss=162495.22
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 2: R²=0.6028 | Loss=162469.10
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 3: R²=0.6031 | Loss=162441.18
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 4: R²=0.6032 | Loss=162419.37
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 5: R²=0.6035 | Loss=162392.93
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 6: R²=0.6036 | Loss=162370.85
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 7: R²=0.6039 | Loss=162345.59
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 8: R²=0.6041 | Loss=162320.24
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 9: R²=0.6043 | Loss=162296.74
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 10: R²=0.6045 | Loss=162272.10
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 11: R²=0.6047 | Loss=162247.32
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 12: R²=0.6049 | Loss=162224.36
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 13: R²=0.6051 | Loss=162198.11
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 14: R²=0.6053 | Loss=162174.23
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 15: R²=0.6055 | Loss=162149.88
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 16: R²=0.6057 | Loss=162124.37
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 17: R²=0.6059 | Loss=162100.83
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 18: R²=0.6061 | Loss=162076.29
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 19: R²=0.6063 | Loss=162053.34
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 20: R²=0.6065 | Loss=162030.30
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 21: R²=0.6067 | Loss=162006.05
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 22: R²=0.6069 | Loss=161981.27
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 23: R²=0.6071 | Loss=161956.92
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 24: R²=0.6074 | Loss=161932.25
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 25: R²=0.6075 | Loss=161908.15
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 26: R²=0.6078 | Loss=161884.51
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 27: R²=0.6079 | Loss=161861.75
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 28: R²=0.6081 | Loss=161836.57
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 29: R²=0.6084 | Loss=161809.34
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 30: R²=0.6086 | Loss=161787.52
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 31: R²=0.6087 | Loss=161764.21
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 32: R²=0.6090 | Loss=161738.00
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 33: R²=0.6091 | Loss=161716.92
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 34: R²=0.6093 | Loss=161694.84
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 35: R²=0.6095 | Loss=161669.65
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 36: R²=0.6097 | Loss=161645.44
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 37: R²=0.6099 | Loss=161623.25
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 38: R²=0.6101 | Loss=161600.68
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 39: R²=0.6103 | Loss=161575.03
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 40: R²=0.6105 | Loss=161549.79
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 41: R²=0.6107 | Loss=161526.88
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 42: R²=0.6109 | Loss=161502.68
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 43: R²=0.6111 | Loss=161479.76
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 44: R²=0.6113 | Loss=161456.68
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 45: R²=0.6115 | Loss=161433.07
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 46: R²=0.6117 | Loss=161406.44
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 47: R²=0.6119 | Loss=161383.08
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 48: R²=0.6121 | Loss=161358.53
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 49: R²=0.6123 | Loss=161334.77
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 50: R²=0.6125 | Loss=161313.92
#
# ======================================================================
# Stage 3 done in 105.6 min | Best Val R²: 0.612
# Stopped at epoch 50 / 50

# %%
# CELL D: Stage 4 — Continue fine-tuning from Stage 3 best checkpoint
import gc, time
import numpy as np
import torch.optim as optim
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm as tqdm_nb

stage4_cfg = dict(
    downsample=1,
    patch_size=64,        # same as Stage 3 fix
    batch_size=16,
    max_epochs=80,        # more room — early stopping will catch plateau
    lr=5e-5,              # halved from Stage 3 — finer updates
    name="stage4_continued",
    accum_steps=4,
)

cfg = stage4_cfg
torch.cuda.empty_cache(); gc.collect()
free_gb = torch.cuda.mem_get_info()[0] / 1e9
print(f"{'='*70}")
print(f"Stage 4 Continued | VRAM free: {free_gb:.1f} GB")
print(f"patch={cfg['patch_size']} ds={cfg['downsample']} "
      f"bs={cfg['batch_size']} max_ep={cfg['max_epochs']} lr={cfg['lr']}")

# Load Stage 3 best weights
best_ckpt_path = Path("models/checkpoints/best_model.pt")
ckpt = torch.load(best_ckpt_path, map_location=device)
model.load_state_dict(ckpt['model_state'])
print(f"✅ Loaded Stage 3 best weights — R²: {ckpt['r2']:.4f} (epoch {ckpt['epoch']})")

# Same dataset as Stage 3
dataset = make_dataset(
    h5_path, normal_data,
    patch_size=cfg['patch_size'],
    stride=cfg['patch_size'] // 2,
    downsample=cfg['downsample']
)
train_sz = int(0.8 * len(dataset))
val_sz   = len(dataset) - train_sz
trainset, valset = torch.utils.data.random_split(
    dataset, [train_sz, val_sz],
    generator=torch.Generator().manual_seed(42)  # same split as Stage 3
)
trainloader = DataLoader(trainset, batch_size=cfg['batch_size'],
                         shuffle=True,  num_workers=0, pin_memory=True)
valloader   = DataLoader(valset,   batch_size=cfg['batch_size'],
                         shuffle=False, num_workers=0, pin_memory=True)
print(f"{len(dataset)} patches | train {train_sz} val {val_sz} | "
      f"{len(trainloader)} train batches | {len(valloader)} val batches")

optimizer = optim.Adam(model.parameters(), lr=cfg['lr'])
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='max', factor=0.5, patience=7)
ACCUM    = cfg['accum_steps']
PATIENCE = 15   # more patience — gains are small but real

history = dict(train_loss=[], train_r2=[], val_loss=[], val_r2=[])
best_r2 = -np.inf
last_improvement_epoch = 0
stage_start = time.time()

epoch_bar = tqdm_nb(range(1, cfg['max_epochs'] + 1),
                    desc="Stage 4 Continued", unit='ep', leave=True)

for epoch in epoch_bar:
    # ── Train ──────────────────────────────────────────────────────
    model.train()
    total_loss = total_r2 = 0
    optimizer.zero_grad()
    batch_bar = tqdm_nb(trainloader, desc='Train', leave=False,
                        unit='batch', mininterval=0.5)
    for i, (X, y) in enumerate(batch_bar, 1):
        X, y  = X.to(device), y.to(device)
        out   = model(X)
        loss  = criterion(out, y) / ACCUM
        loss.backward()
        if i % ACCUM == 0 or i == len(trainloader):
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            optimizer.zero_grad()
        total_loss += loss.item() * ACCUM
        total_r2   += calculate_r2_safe(out.detach(), y.detach())
    n = len(trainloader)
    tr_loss, tr_r2 = total_loss / n, total_r2 / n

    # ── Validate ───────────────────────────────────────────────────
    model.eval()
    vl_loss_sum = vl_r2_sum = 0
    with torch.no_grad():
        for X, y in valloader:
            X, y = X.to(device), y.to(device)
            out  = model(X)
            vl_loss_sum += criterion(out, y).item()
            vl_r2_sum   += calculate_r2_safe(out, y)
    n = len(valloader)
    vl_loss, vl_r2 = vl_loss_sum / n, vl_r2_sum / n

    history['train_loss'].append(tr_loss)
    history['train_r2'].append(tr_r2)
    history['val_loss'].append(vl_loss)
    history['val_r2'].append(vl_r2)

    # ── Checkpoint ─────────────────────────────────────────────────
    is_best = vl_r2 > best_r2
    if is_best:
        best_r2 = vl_r2
        last_improvement_epoch = epoch
        trainer.save_checkpoint(epoch, cfg['name'], vl_loss, vl_r2, is_best=True)
        print(f"\n  ✅ New best at epoch {epoch}: R²={vl_r2:.4f} | Loss={vl_loss:.2f}")

    trainer.save_checkpoint(epoch, cfg['name'], vl_loss, vl_r2, is_best=False)
    epoch_bar.set_postfix(
        trL=f"{tr_loss:.0f}",  trR2=f"{tr_r2:.3f}",
        vlL=f"{vl_loss:.0f}",  vlR2=f"{vl_r2:.3f}",
        best=f"{best_r2:.3f}")
    scheduler.step(vl_r2)

    # ── Early stopping ─────────────────────────────────────────────
    if epoch - last_improvement_epoch >= PATIENCE:
        print(f"\n⏹  Early stopping at epoch {epoch} "
              f"(no improvement for {PATIENCE} epochs)")
        break

stage_mins = (time.time() - stage_start) / 60
print(f"\n{'='*70}")
print(f"Stage 4 done in {stage_mins:.1f} min | Best Val R²: {best_r2:.3f}")
print(f"Stopped at epoch {epoch} / {cfg['max_epochs']}")
# Out:
# ======================================================================
# Stage 4 Continued | VRAM free: 10.0 GB
# patch=64 ds=1 bs=16 max_ep=80 lr=5e-05
# ✅ Loaded Stage 3 best weights — R²: 0.6125 (epoch 50)
# 23112 patches | train 18489 val 4623 | 1156 train batches | 289 val batches
# Stage 4 Continued:   0%|          | 0/80 [00:00<?, ?ep/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 1: R²=0.5717 | Loss=90799.29
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
#   ✅ New best at epoch 4: R²=0.5745 | Loss=90772.22
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# Train:   0%|          | 0/1156 [00:00<?, ?batch/s]
# ⏹  Early stopping at epoch 19 (no improvement for 15 epochs)
#
# ======================================================================
# Stage 4 done in 39.9 min | Best Val R²: 0.575
# Stopped at epoch 19 / 80

# %%
# CELL C: Verify best_model.pt before running NB06
ckpt = torch.load("models/checkpoints/best_model.pt", map_location=device)
print("=" * 70)
print("FINAL CHECKPOINT VERIFICATION")
print("=" * 70)
print(f"  Stage    : {ckpt['stage']}")
print(f"  Epoch    : {ckpt['epoch']}")
print(f"  Val R²   : {ckpt['r2']:.4f}")
print(f"  Val Loss : {ckpt['loss']:.2f}")
print("=" * 70)

if ckpt['r2'] > 0.3:
    print("✅ Model looks good — proceed to NB06")
elif ckpt['r2'] > 0.0:
    print("⚠️  R² < 0.3 — NB06 will work but predictions may be weak")
    print("   Consider extending max_epochs to 80 in Cell B and rerunning")
else:
    print("❌ R² still ≤ 0 — do NOT run NB06 yet")
    raise ValueError(f"Invalid checkpoint R²={ckpt['r2']:.4f}")
# Out:
# ======================================================================
# FINAL CHECKPOINT VERIFICATION
# ======================================================================
#   Stage    : stage4_continued
#   Epoch    : 4
#   Val R²   : 0.5745
#   Val Loss : 90772.22
# ======================================================================
# ✅ Model looks good — proceed to NB06

# %%
# Restore Stage 3 best checkpoint
import torch
from pathlib import Path

ckpt_dir = Path("models/checkpoints")

# Find best Stage 3 checkpoint by R²


stage3_ckpts = sorted(ckpt_dir.glob("ckpt_stage3*ep*.pt"))
best_ckpt, best_r2 = None, -float('inf')
for path in stage3_ckpts:
    ckpt = torch.load(path, map_location=device)
    if ckpt.get('r2', -float('inf')) > best_r2:
        best_r2 = ckpt['r2']
        best_ckpt = (path, ckpt)

path, ckpt = best_ckpt
print(f"✅ Best Stage 3 checkpoint: {path.name}")
print(f"   Epoch: {ckpt['epoch']} | R²: {ckpt['r2']:.4f} | Loss: {ckpt['loss']:.2f}")
torch.save(ckpt, ckpt_dir / "best_model.pt")
print("✅ best_model.pt restored to Stage 3 — ready for NB06")
# Out:
# ✅ Best Stage 3 checkpoint: ckpt_stage3_fine_fixed_ep50.pt
#    Epoch: 50 | R²: 0.6125 | Loss: 161313.92
# ✅ best_model.pt restored to Stage 3 — ready for NB06
