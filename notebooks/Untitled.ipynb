# %%
import sys, os
from pathlib import Path

# Move working directory from /workspace/notebooks → /workspace
project_root = Path.cwd().parent
os.chdir(project_root)
sys.path.insert(0, str(project_root))

print(f"✓ Working dir: {os.getcwd()}")
print(f"✓ data/raw exists: {Path('data/raw').exists()}")
print(f"✓ src exists: {Path('src').exists()}")
# Out:
# ✓ Working dir: /workspace
# ✓ data/raw exists: True
# ✓ src exists: True

# %%
import torch

data = torch.load("models/checkpoints/ckpt_stage4_continued_ep4.pt", map_location='cpu')
print(type(data))
print(data)
# Out:
# <class 'dict'>
# {'epoch': 4, 'stage': 'stage4_continued', 'model_state': OrderedDict({'encoder_cells.0.conv_gates.weight': tensor([[[[ 1.1098e-01,  6.8296e-02,  7.7694e-02],
#           [ 1.7688e-01,  8.3816e-02,  3.2691e-02],
#           [ 1.2924e-01,  6.7243e-02,  4.2675e-02]],
#
#          [[-1.5856e-01, -2.5875e-01, -2.3540e-01],
#           [-1.9233e-01, -3.8699e-01, -3.1256e-01],
#           [ 5.7401e-02, -2.8295e-01, -3.4314e-01]],
#
#          [[-1.0306e-01, -4.0184e-02,  6.3471e-02],
#           [-1.1468e-01, -2.4301e-01,  1.9602e-01],
#           [-4.4333e-01, -1.7511e-01, -1.2466e-01]],
#
#          ...,
#
#          [[-1.9090e-01, -3.8868e-01, -3.2303e-01],
#           [-3.0847e-01, -4.2386e-01, -2.4841e-01],
#           [-2.9523e-01, -2.1196e-01, -1.2044e-01]],
#
#          [[ 1.9557e-01, -6.9639e-02, -2.8455e-01],
#           [ 2.5391e-01,  3.1814e-01,  8.5256e-02],
#           [ 2.4310e-01,  4.7630e-01,  1.8400e-01]],
#
# ...

# %%
import torch
import json
import numpy as np

# Load the checkpoint
checkpoint = torch.load('models/checkpoints/ckpt_stage4_continued_ep4.pt', map_location='cpu')

def to_serializable(obj):
    if isinstance(obj, torch.Tensor):
        return obj.cpu().detach().numpy().tolist()
    elif isinstance(obj, (dict, type(checkpoint['model_state']))):  # handles OrderedDict too
        return {k: to_serializable(v) for k, v in obj.items()}
    elif isinstance(obj, (list, tuple)):
        return [to_serializable(i) for i in obj]
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, (np.integer, np.floating)):
        return obj.item()
    else:
        return obj  # int, float, str — already JSON-safe

output = to_serializable(checkpoint)

with open('checkpoint.json', 'w') as f:
    json.dump(output, f, indent=2)

print("Done! Keys found:", list(output.keys()))
# Out:
# Done! Keys found: ['epoch', 'stage', 'model_state', 'loss', 'r2']
